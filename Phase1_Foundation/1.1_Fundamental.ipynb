# %% [markdown]
# # 1. String

# %%
s = "I love HCMUS"
s.split()
# Out:
# ['I', 'love', 'HCMUS']

# %%
print(s[::-1])
# Out:
# SUMCH evol I

# %%
print(s[1:8:2])
# Out:
#  oeH

# %%
s = "I,love,HCMUS"
s.split(',')
# Out:
# ['I', 'love', 'HCMUS']

# %%
words = ['I', 'love', 'HCMUS']
s = " ".join(words)
s
# Out:
# 'I love HCMUS'

# %%
word = "       I        love       HCMUS      "
print(word.strip())
print(word.lstrip())
print(word.rstrip())
# Out:
# I        love       HCMUS
# I        love       HCMUS
#        I        love       HCMUS

# %%
word = "I love Python"
print(word.replace("love", "hate"))
# Out:
# 'I love Python'

# %%
word = "I love you more than you love me"
word.replace("love", "hate", 1)
# Out:
# 'I hate you more than you love me'

# %%
word = "I love you more than you love me"
parts = word.rsplit("love", 1)
word = "hate".join(parts)
word
# Out:
# 'I love you more than you hate me'

# %%
sentence = "I love Python"
sentence.find("Python")
# Out:
# 7

# %%
sentence = "I love Python"
sentence.find("Pyython")
# Out:
# -1

# %%
sentence = "I love Python"
sentence.startswith("I love")
# Out:
# True

# %%
sentence = "I love Python"
sentence.endswith("Python")
# Out:
# True

# %%
picnic_items = {"sandwiches": 4, "apples": 12, "cups": 4, "cookies": 8000}
print('PICNIC ITEMS'.center(25, '-'))
for k, v in picnic_items.items():
    print(k.ljust(19, '.') + str(v).rjust(6))
# Out:
# -------PICNIC ITEMS------
# sandwiches.........     4
# apples.............    12
# cups...............     4
# cookies............  8000

# %%
spam = "SpamSpamSpampamSILOVEHCMUSSpammpaS"
res = spam.strip('Spam')
print(res)
# cuts the letter 'S', 'p', 'a' and 'm' till it meets the one not in these
# Out:
# ILOVEHCMU

# %% [markdown]
# # 2. List

# %%
spam = ['cat', 'dog', 'butterfly', 'bug']
del spam[2]
spam
# Out:
# ['cat', 'dog', 'bug']

# %%
spam.index('cat')
# Out:
# 0

# %%
spam.insert(2, 'butterfly')
spam
# Out:
# ['cat', 'dog', 'butterfly', 'bug']

# %%
tuple(['fore', 'see', 4])
# Out:
# ('fore', 'see', 4)

# %%
list((4, 'e', 'ver'))
# Out:
# [4, 'e', 'ver']

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
tuple('hello')
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
import copy
spam = list('Hello')
cheese = copy.copy(spam)
cheese[1] = 'i'
print(spam)
print(cheese)
# Out:
# ['H', 'e', 'l', 'l', 'o']
# ['H', 'i', 'l', 'l', 'o']

# %% [markdown]
# Write a function that takes a list value as an argument and returns a string with all the items separated by a comma and a space, with and inserted before the last item. For example, passing the previous spam list to the function would return 'apples, bananas, tofu, and cats'. But your function should be able to work with any list value passed to it

# %%
def link_words(fruit_lst):
    full_comma = ", ".join(fruit_lst)
    lst = full_comma.rsplit(',', 1)
    result = " and".join(lst)
    return result

# %%
link_words(["Banana", "apple", "tomato", "durian"])
# Out:
# 'Banana, apple, tomato and durian'

# %%
numbers = [10, 20, 30]
numbers.extend([40, 50])
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %%
x = numbers.pop()
print(x)
print(numbers)
# Out:
# 50
# [10, 20, 30, 40]

# %%
numbers = [1, 3, 4, 2, 5]
numbers.sort()
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers = [2, 3, 1, 4, 5]
numbers.reverse()
print(numbers)
# Out:
# [5, 4, 1, 3, 2]

# %%
numbers = [2, 3, 4, 1, 5]
sort_lst = sorted(numbers)
print(sort_lst)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # 3. Dictionary

# %%
spam1 = ['dog', 'cat']
spam2 = ['dog', 'cat']
print(spam1 == spam2)
# Out:
# True

# %%
spam1 = {
    'dog': 4,
    'turkey': 2
}
spam2 = {
    'dog': 4,
    'turkey': 2
}
print(spam1 == spam2)
# Out:
# True

# %%
print(spam1.get('dog'))
# Out:
# 4

# %%
print(spam1.get('cat', 1))
# No cat in dictionary
# Out:
# 1

# %%
x = spam1.pop("dog")
print(x)
print(spam1.items())
# Out:
# 4
# dict_items([('turkey', 2)])

# %%
spam = {
    "dog": 4,
    "cat": 4,
    "turkey": 2
}
spam.setdefault('dog', 1)
print(spam)
# Out:
# {'dog': 4, 'cat': 4, 'turkey': 2}

# %%
spam.setdefault('bug', 100)
print(spam)
# Out:
# {'dog': 4, 'cat': 4, 'turkey': 2, 'bug': 100}

# %%
import pprint
pprint.pprint(spam)
# Sort keys based on alphabet
# Out:
# {'bug': 100, 'cat': 4, 'dog': 4, 'turkey': 2}

# %% [markdown]
# ## Fantasy Game Inventory
# You are creating a fantasy video game. The data structure to model the
# player’s inventory will be a dictionary where the keys are string values
# describing the item in the inventory and the value is an integer value detailing how many of that item the player has. For example, the dictionary value
# {'rope': 1, 'torch': 6, 'gold coin': 42, 'dagger': 1, 'arrow': 12} means the
# player has 1 rope, 6 torches, 42 gold coins, and so on. \
# Write a function named displayInventory() that would take any possible
# “inventory” and display it like the following:

# %%
def displayInventory(inventory: dict):
    sum = 0
    print("Inventory:")
    for item, numbers in inventory.items():
        sum += numbers
        print(f"{numbers} {item}")
    print("Total number of items: " + str(sum))

# %%
displayInventory({'rope': 1, 'torch': 6, 'gold coin': 42, 'dagger': 1, 'arrow': 12})
# Out:
# Inventory:
# 1 rope
# 6 torch
# 42 gold coin
# 1 dagger
# 12 arrow
# Total number of items: 62

# %% [markdown]
# ## List to Dictionary Function for Fantasy Game Inventory
# Write a function named addToInventory(inventory, addedItems), where the
# inventory parameter is a dictionary representing the player’s inventory (like
# in the previous project) and the addedItems parameter is a list like dragonLoot.
# The `addToInventory()` function should return a dictionary that represents the
# updated inventory. Note that the addedItems list can contain multiples of the
# same item.

# %%
def addToInventory(inventory: dict, addedItems: list):
    for item in addedItems:
        if item in inventory:
            inventory[item] += 1
        else:
            inventory[item] = 1
    return inventory

# %%
inv = {'gold coin': 42, 'rope': 1}
dragonLoot = ['gold coin', 'dagger', 'gold coin', 'gold coin', 'ruby']
inv = addToInventory(inv, dragonLoot)
displayInventory(inv)
# Out:
# Inventory:
# 45 gold coin
# 1 rope
# 1 dagger
# 1 ruby
# Total number of items: 48

# %% [markdown]
# # 4. Set

# %%
numbers1 = {1, 2, 3, 4, 5}
numbers2 = {1, 2, 4, 7, 9}

# %%
numbers = [1, 2, 2, 3, 3, 4, 3]
numbers_set = set(numbers) # create a set from list
print(numbers_set)
# Out:
# {1, 2, 3, 4}

# %%
numbers_set.add(5)
print(numbers_set)
numbers_set.remove(1)
print(numbers_set)
numbers_set.discard(2)
print(numbers_set)
# Out:
# {1, 2, 3, 4, 5}
# {2, 3, 4, 5}
# {3, 4, 5}

# %%
numbers_set.remove(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 numbers_set.remove(2)
#
# KeyError: 2

# %%
print(numbers1 | numbers2)
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
print(numbers1 & numbers2)
# Out:
# {1, 2, 4}

# %%
print(numbers1 - numbers2)
# Out:
# {3, 5}
